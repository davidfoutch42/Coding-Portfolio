# %%
import pandas as pd
import py3Dmol

df = pd.read_csv("4pld_test.txt", sep="\t")

view = py3Dmol.view(query='pdb:4PLD')
chA = {'chain':'A'}
chB = {'chain':'B'}
view.addSurface(py3Dmol.VDW,{'opacity':0.4,'color':'white'}, chA)
view.setStyle(chA,{'cartoon': {'color':'white'}})
view.setStyle(chB,{'': {'color':None}})
view.setHoverable({},True,'''function(atom,viewer,event,container) {
                   if(!atom.label) {
                    atom.label = viewer.addLabel(atom.resn+":"+atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black'});
                   }}''',
               '''function(atom,viewer) { 
                   if(atom.label) {
                    viewer.removeLabel(atom.label);
                    delete atom.label;
                   }
                }''')



resset = [300,400,401,402,403,404]
for i in resset:
    view.addStyle({'chain':'A','resi': i},{'cartoon':{'color':'red'}})

for i in range(723):
    
    view.addCylinder(
        {'start':dict(x=df.iloc[i][2],y=df.iloc[i][3],z=df.iloc[i][4]),
        'end':dict(x=df.iloc[i][5],y=df.iloc[i][6],z=df.iloc[i][7]),
        'radius':0.12,
        'fromCap':1,
        'toCap':1,
        'color':'teal',
        'dashes':False
        }
    ) 
                                                 
view.render()
# Out:
# <div id="3dmolviewer_16843836915024278"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_16843836915024278" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.3/3Dmol-min.js');
# }
#
# var viewer_16843836915024278 = null;
# var warn = document.getElementById("3dmolwarning_16843836915024278");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16843836915024278 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16843836915024278"),{backgroundColor:"white"});
# $3Dmol.download("pdb:4PLD", viewer_16843836915024278, {}, function() {
# viewer_16843836915024278.zoomTo();
# 	viewer_16843836915024278.addSurface(1,{"opacity": 0.4, "color": "white"},{"chain": "A"});
# 	viewer_16843836915024278.setStyle({"chain": "A"},{"cartoon": {"color": "white"}});
# 	viewer_16843836915024278.setStyle({"chain": "B"},{"": {"color": null}});
# 	viewer_16843836915024278.setHoverable({},true,"function(atom,viewer,event,container) {\n                   if(!atom.label) {\n                    atom.label = viewer.addLabel(atom.resn+\":\"+atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black'});\n                   }}","function(atom,viewer) { \n                   if(atom.label) {\n                    viewer.removeLabel(atom.label);\n                    delete atom.label;\n                   }\n                }");
# 	viewer_16843836915024278.addStyle({"chain": "A", "resi": 300},{"cartoon": {"color": "red"}});
# 	viewer_16843836915024278.addStyle({"chain": "A", "resi": 400},{"cartoon": {"color": "red"}});
# 	viewer_16843836915024278.addStyle({"chain": "A", "resi": 401},{"cartoon": {"color": "red"}});
# 	viewer_16843836915024278.addStyle({"chain": "A", "resi": 402},{"cartoon": {"color": "red"}});
# 	viewer_16843836915024278.addStyle({"chain": "A", "resi": 403},{"cartoon": {"color": "red"}});
# 	viewer_16843836915024278.addStyle({"chain": "A", "resi": 404},{"cartoon": {"color": "red"}});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -32.578, "y": -10.816, "z": -9.81}, "end": {"x": -30.713, "y": -10.222, "z": -3.394}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -31.953, "y": -7.309, "z": -11.185}, "end": {"x": -30.864, "y": -2.398, "z": -15.988}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -31.953, "y": -7.309, "z": -11.185}, "end": {"x": -26.664, "y": 0.07, "z": -17.335}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -31.953, "y": -7.309, "z": -11.185}, "end": {"x": -24.549, "y": -2.778, "z": -11.103}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.129, "y": -4.229, "z": -10.633}, "end": {"x": -30.547, "y": -0.675, "z": -12.625}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.129, "y": -4.229, "z": -10.633}, "end": {"x": -30.864, "y": -2.398, "z": -15.988}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.129, "y": -4.229, "z": -10.633}, "end": {"x": -31.943, "y": 0.969, "z": -17.449}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.129, "y": -4.229, "z": -10.633}, "end": {"x": -32.808, "y": -0.351, "z": -6.046}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.129, "y": -4.229, "z": -10.633}, "end": {"x": -29.948, "y": -5.536, "z": -5.545}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -35.531, "y": -2.759, "z": -13.824}, "end": {"x": -30.864, "y": -2.398, "z": -15.988}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -35.531, "y": -2.759, "z": -13.824}, "end": {"x": -31.943, "y": 0.969, "z": -17.449}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -35.531, "y": -2.759, "z": -13.824}, "end": {"x": -28.961, "y": 2.76, "z": -15.935}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.115, "y": 0.612, "z": -12.842}, "end": {"x": -31.943, "y": 0.969, "z": -17.449}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.115, "y": 0.612, "z": -12.842}, "end": {"x": -28.961, "y": 2.76, "z": -15.935}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.115, "y": 0.612, "z": -12.842}, "end": {"x": -26.664, "y": 0.07, "z": -17.335}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.115, "y": 0.612, "z": -12.842}, "end": {"x": -32.883, "y": 11.059, "z": -16.495}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.115, "y": 0.612, "z": -12.842}, "end": {"x": -35.307, "y": 5.168, "z": -6.325}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.115, "y": 0.612, "z": -12.842}, "end": {"x": -31.625, "y": 4.42, "z": -6.935}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -34.115, "y": 0.612, "z": -12.842}, "end": {"x": -32.808, "y": -0.351, "z": -6.046}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -30.547, "y": -0.675, "z": -12.625}, "end": {"x": -28.961, "y": 2.76, "z": -15.935}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -30.547, "y": -0.675, "z": -12.625}, "end": {"x": -26.664, "y": 0.07, "z": -17.335}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -30.547, "y": -0.675, "z": -12.625}, "end": {"x": -28.035, "y": 0.568, "z": -20.849}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal", "dashes": false});
# 	viewer_16843836915024278.addCylinder({"start": {"x": -30.547, "y": -0.675, "z": -12.625}, "end": {"x": -24.549, "y": -2.778, "z": -11.103}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "teal",

# %%
import matplotlib as mpl
import networkx as nx
import pandas as pd
import random
import numpy as np
from visJS2jupyter import visJS_module

# %%
G = nx.read_adjlist("4pld_edgeList.txt")
nodes = list(G.nodes()) # type cast to list in order to make compatible with networkx 1.11 and 2.0nodes = list(G.nodes()) # type cast to list in order to make compatible with networkx 1.11 and 2.0
edges = list(G.edges()) # for nx 2.0, returns an "EdgeView" object rather than an iterable
# pos = nx.spectral_layout(G)

df = pd.read_csv("4pld_node_pos.txt", sep="\t")

for i in range(239):
    nodes_dict = [{"id":n,
                   "degree":nx.degree(G,n),
                   "x":df.iloc[0][1],
                   "y":df.iloc[0][2]}  for n in nodes
                  ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":'orange',"title":'test'} # remember (source, target, key)
              for i in range(len(edges))]

# set some network-wide styles
visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=3,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=False,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=1,
                          min_velocity=0,
                          edge_smooth_enabled = True)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"id": "300:SER", "degree": 1, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "300:SER"}, {"id": "487:CYS", "degree": 4, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "487:CYS"}, {"id": "301:ILE", "degree": 3, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "301:ILE"}, {"id": "306:LEU", "degree": 6, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "306:LEU"}, {"id": "309:LEU", "degree": 8, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "309:LEU"}, {"id": "446:ARG", "degree": 8, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "446:ARG"}, {"id": "302:PRO", "degree": 5, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "302:PRO"}, {"id": "305:ILE", "degree": 8, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "305:ILE"}, {"id": "307:GLU", "degree": 6, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "307:GLU"}, {"id": "480:ALA", "degree": 9, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "480:ALA"}, {"id": "484:TYR", "degree": 11, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "484:TYR"}, {"id": "303:HIS", "degree": 3, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "303:HIS"}, {"id": "308:LEU", "degree": 9, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "308:LEU"}, {"id": "304:LEU", "degree": 7, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "304:LEU"}, {"id": "365:PHE", "degree": 8, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "365:PHE"}, {"id": "476:GLN", "degree": 7, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "476:GLN"}, {"id": "477:VAL", "degree": 9, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "477:VAL"}, {"id": "310:LYS", "degree": 3, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "310:LYS"}, {"id": "450:CYS", "degree": 9, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "450:CYS"}, {"id": "311:CYS", "degree": 6, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "311:CYS"}, {"id": "364:ILE", "degree": 5, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "364:ILE"}, {"id": "312:GLU", "degree": 6, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "312:GLU"}, {"id": "449:VAL", "degree": 9, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "449:VAL"}, {"id": "453:PHE", "degree": 10, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "453:PHE"}, {"id": "445:GLN", "degree": 6, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "445:GLN"}, {"id": "359:TRP", "degree": 11, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "359:TRP"}, {"id": "363:SER", "degree": 8, "x": -32.578, "y": -10.816, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "363:SER"}, {"id": "452:LYS", "de ...

# %%
print(pos)

# %%
df = pd.read_csv("4pld_node_pos.txt", sep="\t")
print(nodes_dict)
