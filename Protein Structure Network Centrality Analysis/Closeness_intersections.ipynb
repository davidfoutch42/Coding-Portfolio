# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import networkx as nx
import numpy as np
import pandas as pd
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

def print_top(lst,num):
     #Print the top num items of lst in decreasing order
        s=sorted(lst,key=lambda item: -lst[item])
        print("\tValue\tNode")
        for i in range(0,min(num,len(s))):
             print("{0}\t{1}\t{2}".format(i+1,lst[s[i]],s[i]))
                
def new_list(lst,num):
    s=sorted(lst,key=lambda item: -lst[item])
    newlst = []
    for i in range(0,min(num,len(s))):
        newlst.append(s[i])
#     print(newlst)
    return(newlst)

def sort_list(filename,mylist,num):
    s=sorted(mylist,key=lambda item: -mylist[item])
    with open(filename, 'w') as f:
        for i in range(0,min(num,len(s))):
            print("{0}\t{1}\t{2}".format(i+1,mylist[s[i]],s[i]), file = f) 
            
def make_list(lst,filename):
    s=list(dict.items(lst))
    with open(filename, 'w') as f:
        for i in range(0,len(s)):
            t=s[i][0]
            fst=t[4:]
            print("{0}\t{1}".format(fst,s[i][1]), file = f) 
            
def sort_list2(mylist,filename):
    s=sorted(mylist,key=lambda item: -mylist[item])
    with open(filename, 'w') as f:
        for i in range(0,len(s)):
            print("{0}\t{1}".format(s[i],mylist[s[i]]), file = f)

# %%
graph="mCAR.adj_list"
g=nx.read_adjlist(graph,create_using=nx.Graph(),nodetype=str)
close_centr=nx.closeness_centrality(g, u=None)
sort_list2(close_centr,'close_mCAR')
##################################################################

graph="mTCP.adj_list"
g=nx.read_adjlist(graph,create_using=nx.Graph(),nodetype=str)
close_centr=nx.closeness_centrality(g, u=None)
sort_list2(close_centr,'close_mTCP')
###################################################################

graph="hCIT.adj_list"
g=nx.read_adjlist(graph,create_using=nx.Graph(),nodetype=str)
close_centr=nx.closeness_centrality(g, u=None)
sort_list2(close_centr,'close_hCIT')
###################################################################

graph="000.adj_list"
g=nx.read_adjlist(graph,create_using=nx.Graph(),nodetype=str)
close_centr=nx.closeness_centrality(g, u=None)
sort_list2(close_centr,'close_000')
###################################################################

graph="0T0.adj_list"
g=nx.read_adjlist(graph,create_using=nx.Graph(),nodetype=str)
close_centr=nx.closeness_centrality(g, u=None)
sort_list2(close_centr,'close_0T0')
###################################################################

graph="AT0.adj_list"
g=nx.read_adjlist(graph,create_using=nx.Graph(),nodetype=str)
close_centr=nx.closeness_centrality(g, u=None)
sort_list2(close_centr,'close_AT0')
####################################################################

graph="dAT0.adj_list"
g=nx.read_adjlist(graph,create_using=nx.Graph(),nodetype=str)
close_centr=nx.closeness_centrality(g, u=None)
sort_list2(close_centr,'close_dAT0')

# %%
# %%bash
#
# # Make a second mCAR closeness file for comparison with hCAR
#
# cp close_mCAR temp
# cut -f1 temp > temp2
# sed -e 's/^.*_//g' temp2 > temp3
# awk '{print $1+106}' temp3 > temp4
# sed -e 's/[0-9]\+//g' temp2 > temp3
# paste temp3 temp4 | sed 's/\t//g' > temp5
# paste temp temp5 | awk '{print $3"\t"$2}' > close_mCAR2
# rm temp*

# %%
# %%bash
# awk 'NR==FNR {a[$1]=$2; next} $1 in a {print $0, a[$1]}' OFS='\t' close_mTCP close_mCAR > temp
# cut -f 1,3 -d$'\t' temp | sort -k2 -n -r > temp2
# paste -d'\t' temp temp2 | cut -d$'\t' -f 1,2,4,5  > scatter_close_mCAR_mTCP

# %%
# %%bash
# awk 'NR==FNR {a[$1]=$2; next} $1 in a {print $0, a[$1]}' OFS='\t' close_mTCP close_mCAR > scatter_close_mCAR_mTCP2

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.style.use('ggplot')

plt.figure(figsize=(12,7))
df1=pd.read_csv('scatter_close_mCAR_mTCP2',sep='\t',header=None)
plt.scatter(df1[1], df1[2],color='royalblue',edgecolor='cyan',zorder=3,s=30,label="mCAR residues")

plt.plot(np.unique(df1[1]), np.poly1d(np.polyfit(df1[1], df1[2], 1))(np.unique(df1[1])),alpha=0.5,color="red")
# plt.axvline(df1.iloc[39,1], color='r', linestyle='dashed', linewidth=2, label='cutoff')
plt.legend(shadow=True,facecolor='white',loc='upper left',fontsize=16)
plt.xticks(np.arange(0.15, 0.35, 0.05))
plt.yticks(np.arange(0.15, 0.35, 0.05))
plt.xlabel('mCAR Residues',fontsize=20,color='black',labelpad=5)
plt.ylabel('TCP-mCAR Residues',fontsize=20,color='black',labelpad=5)
# plt.text(0.218,0.175,'16%% cutoff=%.4f' %(df1.iloc[39,1]),fontsize=16,color='k',bbox=dict(facecolor='w',edgecolor='none'))
plt.savefig('CAR_Closeness_scatterplot.png')
plt.show()

# %%
f, ax = plt.subplots(figsize=(12, 7))
df1=pd.read_csv('scatter_close_mCAR_mTCP2',sep='\t',header=None)
sns.scatterplot(df1[1], df1[2], ax=ax, color="green",s=30,label="mCAR x TCP-mCAR")
sns.rugplot(df1[1], color="gray", axis='x')
sns.rugplot(df1[2], color="gray", axis='y', height=0.025);

plt.legend(shadow=True,facecolor='white',loc='upper left',fontsize=22)
plt.xlabel('mCAR CC Values',fontsize=30,color='black',labelpad=5)
plt.ylabel('TCP-mCAR CC Values',fontsize=30,color='black',labelpad=5)

plt.xlim(0.1382,0.32)
plt.ylim(0.1382,0.33)
plt.xticks(np.arange(0.15, 0.32, 0.02))
plt.yticks(np.arange(0.15, 0.33, 0.02))


plt.tick_params(axis = 'both', which = 'major', labelsize = 16)
plt.savefig('CAR_Closeness_scatterplot.png')
plt.show()

# %%
# %%bash
# awk 'NR==FNR {a[$1]=$2; next} $1 in a {print $0, a[$1]}' OFS='\t' close_hCIT close_mCAR2 > temp
# cut -f 1,3 -d$'\t' temp | sort -k2 -n -r > temp2
# paste -d'\t' temp temp2 | cut -d$'\t' -f 1,2,4,5  > scatter_close_mCAR_hCIT

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.style.use('ggplot')

plt.figure(figsize=(12,7))
df1=pd.read_csv('scatter_close_mCAR_hCIT',sep='\t',header=None)
plt.scatter(df1[1], df1[3],color='royalblue',edgecolor='cyan',zorder=3,s=30,label="mCAR x CIT-hCAR")
plt.plot(np.unique(df1[1]), np.poly1d(np.polyfit(df1[1], df1[3], 1))(np.unique(df1[1])),alpha=0.5,color="gray")
plt.axvline(df1.iloc[39,1], color='r', linestyle='dashed', linewidth=2, label='cutoff')
plt.legend(shadow=True,facecolor='white',loc='upper left',fontsize=16)
plt.xlabel('mCAR Closeness Centrality',fontsize=20,color='black',labelpad=5)
plt.ylabel('CIT-hCAR Closeness Centrality',fontsize=20,color='black',labelpad=5)
plt.text(0.223,0.18,'cutoff=%.4f' %(df1.iloc[39,1]),fontsize=16,color='k',bbox=dict(facecolor='w',edgecolor='none'))
plt.savefig('mCAR-hCAR_Closeness_scatterplot.png')
plt.show()

# %%
# %%bash
# awk 'NR==FNR {a[$1]=$2; next} $1 in a {print $0, a[$1]}' OFS='\t' close_000 close_0T0 > temp
# cut -f 1,3 -d$'\t' temp | sort -k2 -n -r > temp2
# paste -d'\t' temp temp2 | cut -d$'\t' -f 1,2,4,5  > scatter_close_000_0T0

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.style.use('ggplot')

plt.figure(figsize=(12,7))
df=pd.read_csv('scatter_close_000_0T0',sep='\t',header=None)
plt.scatter(df[1], df[3],color='royalblue',edgecolor='cyan',zorder=3,s=30,label="000-RNR x 0T0-RNR")

df.drop(df.tail(7).index,inplace=True)
plt.plot(np.unique(df[1]), np.poly1d(np.polyfit(df[1], df[3], 1))(np.unique(df[1])),alpha=0.5,color="gray")

plt.axvline(df.iloc[119,1], color='r', linestyle='dashed', linewidth=2, label='cutoff')
plt.legend(shadow=True,facecolor='white',loc='upper left',fontsize=16)
plt.xlabel('000-RNR Closeness Centrality',fontsize=20,color='black',labelpad=5)
plt.ylabel('0T0-RNR Closeness Centrality',fontsize=20,color='black',labelpad=5)
plt.text(0.133,0.12,'cutoff=%.4f' %(df.iloc[119,1]),fontsize=16,color='k',bbox=dict(facecolor='w',edgecolor='none'))
plt.savefig('000-0T0_Closeness_scatterplot.png')
plt.show()

# %%
# %%bash
# awk 'NR==FNR {a[$1]=$2; next} $1 in a {print $0, a[$1]}' OFS='\t' close_000 close_AT0 > temp
# cut -f 1,3 -d$'\t' temp | sort -k2 -n -r > temp2
# paste -d'\t' temp temp2 | cut -d$'\t' -f 1,2,4,5  > scatter_close_000_AT0

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.style.use('ggplot')

plt.figure(figsize=(12,7))
df=pd.read_csv('scatter_close_000_AT0',sep='\t',header=None)
plt.scatter(df[1], df[3],color='royalblue',edgecolor='cyan',zorder=3,s=30,label="000-RNR x AT0-RNR")
plt.plot(np.unique(df[1]), np.poly1d(np.polyfit(df[1], df[3], 1))(np.unique(df[1])),alpha=0.5,color="gray")

plt.axvline(df.iloc[119,1], color='r', linestyle='dashed', linewidth=2, label='cutoff')
plt.legend(shadow=True,facecolor='white',loc='upper left',fontsize=16)
plt.xlabel('000-RNR Closeness Centrality',fontsize=20,color='black',labelpad=5)
plt.ylabel('AT0-RNR Closeness Centrality',fontsize=20,color='black',labelpad=5)
plt.text(0.156,0.12,'cutoff=%.4f' %(df.iloc[119,1]),fontsize=16,color='k',bbox=dict(facecolor='w',edgecolor='none'))
plt.savefig('000-AT0_Closeness_scatterplot.png')
plt.show()

# %%
# %%bash
# awk 'NR==FNR {a[$1]=$2; next} $1 in a {print $0, a[$1]}' OFS='\t' close_000 close_dAT0 > temp
# cut -f 1,3 -d$'\t' temp | sort -k2 -n -r > temp2
# paste -d'\t' temp temp2 | cut -d$'\t' -f 1,2,4,5  > scatter_close_000_dAT0

# %%
# %%bash
# awk 'NR==FNR {a[$1]=$2; next} $1 in a {print $0, a[$1]}' OFS='\t' close_000 close_dAT0 > scatter_close_000_dAT02

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.style.use('ggplot')

plt.figure(figsize=(12,7))
df=pd.read_csv('scatter_close_000_dAT02',sep='\t',header=None)
plt.scatter(df[1], df[2],color='royalblue',edgecolor='cyan',zorder=3,s=30,label="RNR residues")

df.drop(df.tail(7).index,inplace=True)
plt.plot(np.unique(df[1]), np.poly1d(np.polyfit(df[1], df[2], 1))(np.unique(df[1])),alpha=0.5,color="red")

# plt.axvline(df.iloc[119,1], color='r', linestyle='dashed', linewidth=2, label='cutoff')
plt.legend(shadow=True,facecolor='white',loc='upper left',fontsize=16)
plt.xticks(np.arange(0.00, 0.25, 0.05))
plt.xticks(np.arange(0.00, 0.25, 0.05))
plt.xlabel('000-RNR Residues',fontsize=20,color='black',labelpad=5)
plt.ylabel('dAT0-RNR Residues',fontsize=20,color='black',labelpad=5)
# plt.text(0.12,0.08,'16%% cutoff=%.4f' %(df.iloc[119,1]),fontsize=16,color='k',bbox=dict(facecolor='w',edgecolor='none'))
plt.savefig('000-dAT0_Closeness_scatterplot.png')
plt.show()

# %%
f, ax = plt.subplots(figsize=(12, 7))
df1=pd.read_csv('scatter_close_000_dAT02',sep='\t',header=None)
sns.scatterplot(df1[1], df1[2], ax=ax, color="green",s=30,label="000-RNR x dAT0-RNR")
sns.rugplot(df1[1], color="gray", axis='x')
sns.rugplot(df1[2], color="gray", axis='y', height=0.025);

plt.legend(shadow=True,facecolor='white',loc='upper left',fontsize=22)
plt.xlabel('000-RNR CC Values',fontsize=30,color='black',labelpad=5)
plt.ylabel('dAT0-RNR CC Values',fontsize=30,color='black',labelpad=5)

plt.xlim(0.092,0.23)
plt.ylim(0.092,0.24)
plt.xticks(np.arange(0.10, 0.231, 0.02))
plt.yticks(np.arange(0.10, 0.24, 0.02))
plt.tick_params(axis = 'both', which = 'major', labelsize = 16)
plt.savefig('RNR_Closeness_scatterplot.png')
plt.show()

# %%
df1=pd.read_csv('scatter_close_mCAR_mTCP',sep='\t',header=None)
plt.figure(figsize=(12,9))
A=df1.iloc[0:40][0]
B=df1.iloc[0:40][2]
out=venn2([set(A), set(B)],set_labels=('mCAR','TCP-mCAR'))
for text in out.set_labels:
    text.set_fontsize(22)
for text in out.subset_labels:
    text.set_fontsize(16)

plt.savefig('CAR_Close_intersections.png')
    
plt.show()

# %%
df1=pd.read_csv('scatter_close_mCAR_hCIT',sep='\t',header=None)
plt.figure(figsize=(12,9))
A=df1.iloc[0:40][0]
B=df1.iloc[0:40][2]
out=venn2([set(A), set(B)],set_labels=('mCAR','CIT-hCAR'))
for text in out.set_labels:
    text.set_fontsize(22)
for text in out.subset_labels:
    text.set_fontsize(16)

plt.savefig('mCAR-hCAR_Close_intersections.png')
    
plt.show()

# %%
df1=pd.read_csv('scatter_close_000_0T0',sep='\t',header=None)
plt.figure(figsize=(12,9))
A=df1.iloc[0:120][0]
B=df1.iloc[0:120][2]
out=venn2([set(A), set(B)],set_labels=('000-RNR','0T0-RNR'))
for text in out.set_labels:
    text.set_fontsize(22)
for text in out.subset_labels:
    text.set_fontsize(16)

plt.savefig('000-0T0_Close_intersections.png')
    
plt.show()

# %%
df1=pd.read_csv('scatter_close_000_AT0',sep='\t',header=None)
plt.figure(figsize=(12,9))
A=df1.iloc[0:120][0]
B=df1.iloc[0:120][2]
out=venn2([set(A), set(B)],set_labels=('000-RNR','AT0-RNR'))
for text in out.set_labels:
    text.set_fontsize(22)
for text in out.subset_labels:
    text.set_fontsize(16)

plt.savefig('000-AT0_Close_intersections.png')
    
plt.show()

# %%
df1=pd.read_csv('scatter_close_000_dAT0',sep='\t',header=None)
plt.figure(figsize=(12,9))
A=df1.iloc[0:120][0]
B=df1.iloc[0:120][2]
out=venn2([set(A), set(B)],set_labels=('000-RNR','dAT0-RNR'))
for text in out.set_labels:
    text.set_fontsize(22)
for text in out.subset_labels:
    text.set_fontsize(16)

plt.savefig('000-dAT0_Close_intersections.png')
    
plt.show()

# %%
# %%bash
# head -n 40 scatter_close_mCAR_mTCP  | awk '{print $1}' > temp
# head -n 40 scatter_close_mCAR_mTCP  | awk '{print $3}' >> temp
# sort temp | uniq -d > temp2 #the intersection
# sort temp | uniq -u > temp3 #total outside the intersection
# cp temp2 tmp2
# cp temp2 tmp3
# head -n 40 scatter_close_mCAR_mTCP  | awk '{print $1}' >> tmp2
# sort tmp2 | uniq -u > tmp && mv tmp tmp2 #outside the intersection mCAR
# head -n 40 scatter_close_mCAR_mTCP  | awk '{print $3}' >> tmp3
# sort tmp3 | uniq -u > tmp && mv tmp tmp3 #outside the intersection mTCP
#
# awk '{gsub(/[^0-9.]/,"")}1' temp2 > tmp && mv tmp temp2
# awk '{print "select"" "":"$1}' temp2 > join_mCAR-mTCP.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp2 > tmp && mv tmp tmp2
# awk '{print "select"" "":"$1}' tmp2 > notjoin_mCAR-mTCP.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp3 > tmp && mv tmp tmp3
# awk '{print "select"" "":"$1}' tmp3 > notjoin_mTCP-mCAR.cmd
# rm tmp* temp*

# %%
# %%bash
# head -n 40 scatter_close_mCAR_hCIT  | awk '{print $1}' > temp
# head -n 40 scatter_close_mCAR_hCIT  | awk '{print $3}' >> temp
# sort temp | uniq -d > temp2 #the intersection
# sort temp | uniq -u > temp3 #total outside the intersection
# cp temp2 tmp2
# cp temp2 tmp3
# head -n 40 scatter_close_mCAR_hCIT  | awk '{print $1}' >> tmp2
# sort tmp2 | uniq -u > tmp && mv tmp tmp2 #outside the intersection mCAR
# head -n 40 scatter_close_mCAR_hCIT  | awk '{print $3}' >> tmp3
# sort tmp3 | uniq -u > tmp && mv tmp tmp3 #outside the intersection hCIT
#
# awk '{gsub(/[^0-9.]/,"")}1' temp2 > tmp && mv tmp temp2
# awk '{print "select"" "":"$1}' temp2 > join_mCAR-hCIT.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp2 > tmp && mv tmp tmp2
# awk '{print "select"" "":"$1}' tmp2 > notjoin_mCAR-hCIT.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp3 > tmp && mv tmp tmp3
# awk '{print "select"" "":"$1}' tmp3 > notjoin_hCIT-mCAR.cmd
# # rm tmp* temp*

# %%
# %%bash
# head -n 120 scatter_close_000_0T0  | awk '{print $1}' > temp
# head -n 120 scatter_close_000_0T0  | awk '{print $3}' >> temp
# sort temp | uniq -d > temp2 #the intersection
# sort temp | uniq -u > temp3 #total outside the intersection
# cp temp2 tmp2
# cp temp2 tmp3
# head -n 120 scatter_close_000_0T0  | awk '{print $1}' >> tmp2
# sort tmp2 | uniq -u > tmp && mv tmp tmp2 #outside the intersection 000
# head -n 120 scatter_close_000_0T0  | awk '{print $3}' >> tmp3
# sort tmp3 | uniq -u > tmp && mv tmp tmp3 #outside the intersection 0T0
#
# awk '{gsub(/[^0-9.]/,"")}1' temp2 > tmp && mv tmp temp2
# awk '{print "select"" "":"$1}' temp2 > join_000_0T0.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp2 > tmp && mv tmp tmp2
# awk '{print "select"" "":"$1}' tmp2 > notjoin_000-0T0.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp3 > tmp && mv tmp tmp3
# awk '{print "select"" "":"$1}' tmp3 > notjoin_0T0-000.cmd
# rm tmp* temp*

# %%
# %%bash
# head -n 120 scatter_close_000_AT0  | awk '{print $1}' > temp
# head -n 120 scatter_close_000_AT0  | awk '{print $3}' >> temp
# sort temp | uniq -d > temp2 #the intersection
# sort temp | uniq -u > temp3 #total outside the intersection
# cp temp2 tmp2
# cp temp2 tmp3
# head -n 120 scatter_close_000_AT0  | awk '{print $1}' >> tmp2
# sort tmp2 | uniq -u > tmp && mv tmp tmp2 #outside the intersection 000
# head -n 120 scatter_close_000_AT0  | awk '{print $3}' >> tmp3
# sort tmp3 | uniq -u > tmp && mv tmp tmp3 #outside the intersection AT0
#
# awk '{gsub(/[^0-9.]/,"")}1' temp2 > tmp && mv tmp temp2
# awk '{print "select"" "":"$1}' temp2 > join_000-AT0.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp2 > tmp && mv tmp tmp2
# awk '{print "select"" "":"$1}' tmp2 > notjoin_000-AT0.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp3 > tmp && mv tmp tmp3
# awk '{print "select"" "":"$1}' tmp3 > notjoin_AT0-000.cmd
# rm tmp* temp*

# %%
# %%bash
# head -n 120 scatter_close_000_dAT0  | awk '{print $1}' > temp
# head -n 120 scatter_close_000_dAT0  | awk '{print $3}' >> temp
# sort temp | uniq -d > temp2 #the intersection
# sort temp | uniq -u > temp3 #total outside the intersection
# cp temp2 tmp2
# cp temp2 tmp3
# head -n 120 scatter_close_000_dAT0  | awk '{print $1}' >> tmp2
# sort tmp2 | uniq -u > tmp && mv tmp tmp2 #outside the intersection 000
# head -n 120 scatter_close_000_dAT0  | awk '{print $3}' >> tmp3
# sort tmp3 | uniq -u > tmp && mv tmp tmp3 #outside the intersection dAT0
#
# awk '{gsub(/[^0-9.]/,"")}1' temp2 > tmp && mv tmp temp2
# awk '{print "select"" "":"$1}' temp2 > join_000-dAT0.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp2 > tmp && mv tmp tmp2
# awk '{print "select"" "":"$1}' tmp2 > notjoin_000-dAT0.cmd
# awk '{gsub(/[^0-9.]/,"")}1' tmp3 > tmp && mv tmp tmp3
# awk '{print "select"" "":"$1}' tmp3 > notjoin_dAT0-000.cmd
# rm tmp* temp*

# %% [markdown]
# # Closeness Assignment Files

# %%
# %%bash
#
#
# cut -f 3 -d$'\t' mCAR_close | awk '{gsub(/[^0-9. ]/,"")}1' > temp
# cut -f 2 -d$'\t' mCAR_close > temp2
# paste -d' ' <(awk '{print " "$1}' temp ) <(awk '{print "\t"$1}' temp2 ) |sed 's/ //g' | sort -k1 -n | awk '{print "\t"":"$1"\t"$2}' > mCAR_close.asn
#
# cut -f 3 -d$'\t' mTCP_close | awk '{gsub(/[^0-9. ]/,"")}1' > temp
# cut -f 2 -d$'\t' mTCP_close > temp2
# paste -d' ' <(awk '{print " "$1}' temp ) <(awk '{print "\t"$1}' temp2 ) |sed 's/ //g' | sort -k1 -n | awk '{print "\t"":"$1"\t"$2}' > mTCP_close.asn
#
# cut -f 3 -d$'\t' hCAR_close | awk '{gsub(/[^0-9. ]/,"")}1' > temp
# cut -f 2 -d$'\t' hCAR_close > temp2
# paste -d' ' <(awk '{print " "$1}' temp ) <(awk '{print "\t"$1}' temp2 ) |sed 's/ //g' | sort -k1 -n | awk '{print "\t"":"$1"\t"$2}' > hCAR_close.asn
#
# cut -f 3 -d$'\t' 000_close | awk '{gsub(/[^0-9. ]/,"")}1' > temp
# cut -f 2 -d$'\t' 000_close > temp2
# paste -d' ' <(awk '{print " "$1}' temp ) <(awk '{print "\t"$1}' temp2 ) |sed 's/ //g' | sort -k1 -n | awk '{print "\t"":"$1"\t"$2}' > 000_close.asn
#
# cut -f 3 -d$'\t' 0T0_close | awk '{gsub(/[^0-9. ]/,"")}1' > temp
# cut -f 2 -d$'\t' 0T0_close > temp2
# paste -d' ' <(awk '{print " "$1}' temp ) <(awk '{print "\t"$1}' temp2 ) |sed 's/ //g' | sort -k1 -n | awk '{print "\t"":"$1"\t"$2}' > 0T0_close.asn
#
# cut -f 3 -d$'\t' AT0_close | awk '{gsub(/[^0-9. ]/,"")}1' > temp
# cut -f 2 -d$'\t' AT0_close > temp2
# paste -d' ' <(awk '{print " "$1}' temp ) <(awk '{print "\t"$1}' temp2 ) |sed 's/ //g' | sort -k1 -n | awk '{print "\t"":"$1"\t"$2}' > AT0_close.asn
#
# cut -f 3 -d$'\t' dAT0_close | awk '{gsub(/[^0-9. ]/,"")}1' > temp
# cut -f 2 -d$'\t' dAT0_close > temp2
# paste -d' ' <(awk '{print " "$1}' temp ) <(awk '{print "\t"$1}' temp2 ) |sed 's/ //g' | sort -k1 -n | awk '{print "\t"":"$1"\t"$2}' > dAT0_close.asn
